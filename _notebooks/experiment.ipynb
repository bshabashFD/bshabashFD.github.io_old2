# %%
import plotly.graph_objects as go
import numpy as np
y = np.sort(np.random.normal(size = 1000))
chartdata = go.Scatter(y=y)
fig = go.Figure(
    data=[chartdata],
)
fig.show("png")

# %%
import plotly
plotly.__version__
# Out:
# '4.1.0'

# %%
conda install -c plotly plotly-orca
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - plotly-orca
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py37_1         156 KB
#     conda-4.8.3                |           py37_0         3.0 MB
#     plotly-orca-1.3.1          |                1        56.8 MB  plotly
#     ------------------------------------------------------------
#                                            Total:        60.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly-orca        plotly/osx-64::plotly-orca-1.3.1-1
#
# The following packages will be UPDATED:
#
#   certifi                                 2019.11.28-py37_0 --> 2019.11.28-py37_1
#   conda                                        4.8.2-py37_0 --> 4.8.3-py37_0
# ...

# %%
import IPython
IPython.display.IFrame(https://github.com/bshabashFD/bshabashFD.github.io/blob/master/assets/plotly/Linear%20Regression%20run%20times.html, width=700, height=350)
# Out:
# <iframe src="https://www.youtube.com/watch?v=RMPRh_ly6JM"></iframe>
#         <iframe
#             width="700"
#             height="350"
#             src="<iframe src="https://www.youtube.com/watch?v=RMPRh_ly6JM"></iframe>"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame    
IFrame("https://github.com/bshabashFD/bshabashFD.github.io/blob/master/assets/plotly/Linear%20Regression%20run%20times.html", width=560, height=315)
# Out:
#         <iframe
#             width="560"
#             height="315"
#             src="https://github.com/bshabashFD/bshabashFD.github.io"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
